# %% [markdown]
# # Recurrance relation Assignment

# %% [markdown]
# ![_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![_3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![_4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![_5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![_6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![_7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![_8.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # End
